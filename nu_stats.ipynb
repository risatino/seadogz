# %%
#import dependencies
import pandas as pd
import numpy as np

#read in CSVs
nu_data = "nu_mens_bball_stats.csv"
nu_stats = pd.read_csv(nu_data)

# %%
#drop unecessary columns
nu_stats_final = nu_stats[['Player','Opponent','Date','Start?','min','fgm/a','pct','3fg/a','pct.1','ftm/a','pct.2','off','def','tot','avg','pf','AST','T/O','BLK','STl','PTS','avg.1']]
nu_stats_final
# Out:
#             Player        Opponent        Date Start?  min    fgm/a   pct  \
# 0          Vic Law    Loyola (Md.)  11/10/2017    Yes   35     4-12  0.33
# 1          Vic Law   Saint Peter's  11/13/2017    Yes   35      4-8  0.50
# 2          Vic Law       Creighton  11/15/2017    Yes   39    11-19  0.58
# 3          Vic Law        La Salle  11/18/2017    Yes   33     4-11  0.36
# 4          Vic Law      Texas Tech  11/19/2017    Yes   31      1-6  0.17
# 5          Vic Law    Sacred Heart  11/24/2017    Yes   29      5-9  0.56
# 6          Vic Law    Georgia Tech  11/28/2017    Yes   33      5-8  0.63
# 7          Vic Law        Illinois   12/1/2017    Yes   35     6-11  0.55
# 8          Vic Law          Purdue   12/3/2017    Yes   33      4-9  0.44
# 9          Vic Law   Chicago State  12/11/2017    Yes   17      4-6  0.67
# 10         Vic Law      Valparaiso  12/14/2017    Yes   25      5-9  0.56
# 11         Vic Law          DePaul  12/16/2017    Yes   13      3-5  0.60
# ...

# %%
#Games played, minus 1 to account for total
nu_stats_final['Player'].value_counts()-1
# Out:
# Dererk Pardon         32
# Scottie Lindsey       32
# Anthony Gaines        32
# Gavin Skelly          32
# Barret Benson         32
# Bryant McIntosh       29
# Aaron Falzon          28
# Vic Law               27
# Jordan Ash            25
# Isiah Brown           25
# Tino Malnati           9
# Charlie Hall           4
# Rapolas Ivanauskas     3
# Name: Player, dtype: int64
